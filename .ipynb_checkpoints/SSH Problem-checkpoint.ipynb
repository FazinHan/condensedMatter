# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as linalg
import pandas as pd

# %%
N = 10
t1 = -1
t2 = -1.2

# %%
def mat_plot(matrix):
    plt.imshow(matrix)
    plt.colorbar()
    plt.show()

def kron_sum(A, B):
    return np.kron(A, np.eye(B.shape[0]))+np.kron(np.eye(A.shape[0]),B)

# %%
H = np.zeros((2*N,2*N))

for i in range(N, 2*N):
    H[i, i-N]=-t1
    H[i-N,i]=-t1
for i in range(N,2*N-1):
    H[i,i-N+1]=-t2
    H[i-N+1,i]=-t2
H[-1,0],H[0,-1]=(-t2,-t2)

# pd.DataFrame(H)
mat_plot(H)

# %%
U = np.zeros((N,N))

for i in range(N-1):
    U[i+1,i] = 1
else:
    U[0,N-1] = 1

mat_plot(U)

# %%
kron_matrix = np.array([[0,1],[0,0]])

trans_mat = (-t2)*U + (-t1)*np.eye(N)
trans_mat = np.kron(kron_matrix, trans_mat)

H_ = trans_mat + trans_mat.conj().T

mat_plot(H_)

# %%
vals, vecs = np.linalg.eig(U)

P_matrix = np.kron(kron_matrix, vecs) + np.kron(kron_matrix, vecs).T

# mat_plot(1j*np.log(vals)
mat_plot((np.log(P_matrix)).real)
# Out:
# C:\Users\freak\AppData\Local\Temp\ipykernel_19988\4143266.py:6: RuntimeWarning: divide by zero encountered in log
#   mat_plot((np.log(P_matrix)).real)

# %%
mat_plot((P_matrix.conj().T @ H_ @ P_matrix).real)
